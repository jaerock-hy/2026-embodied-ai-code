# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        return "Woof!"

# %%
a = Dog("Buddy", 3)

# %%
a.bark()
# Out:
# 'Woof!'

# %%
b = Dog("Max", 5)

# %%
b.bark()
# Out:
# 'Woof!'
